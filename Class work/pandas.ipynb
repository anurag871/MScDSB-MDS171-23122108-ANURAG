# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-2.1.1-cp311-cp311-win_amd64.whl (10.6 MB)
# ...
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                              0.0/15.8 MB 640.0 kB/s eta 0:00:25
#                                              0.0/15.8 MB 326.8 kB/s eta 0:00:49
#                                              0.1/15.8 MB 581.0 kB/s eta 0:00:28
#                                              0.1/15.8 MB 774.0 kB/s eta 0:00:21
#                                              0.2/15.8 MB 888.4 kB/s eta 0:00:18
#                                              0.3/15.8 MB 923.9 kB/s eta 0:00:17
#                                              0.3/15.8 MB 923.9 kB/s eta 0:00:17
#                                              0.3/15.8 MB 923.9 kB/s eta 0:00:17
#                                              0.3/15.8 MB 923.9 kB/s eta 0:00:17
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("csv file.csv")

# %%
pd
# Out:
# <module 'pandas' from 'c:\\Users\\Anurag Yadav\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
df.tail()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0

# %%
#create a pandas class_NAME that will help you to read a csv file and print the top/bottom
 # n rows in the file

# %%
#CREATE a petstore class where u have the details of pets available and their details...

#the class will have met hods 
# store  a new pet deatails 
# search for a pet
# list all pets 

# IMPORTING ur petstore class , create a petstore main file , where you will impliment a menu driven program for a admin- 
#who will manage the store & user who will see the pets and buy pets.
