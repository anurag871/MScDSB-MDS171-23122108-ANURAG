# %%
class store:
    def __init__(self):
        self.inventory={}

# Create Inventory
    def create_inventory(self):
        name = input("enter the name")
        price = input("enter price")
        quanity = input("enter quantity ")

        value = {
            "name" : name,
            "price" : price,
            "quantity" : quanity
        }

        self.inventory[name] = value 
        with open("store.csv" , "a") as file:
            file.write(f"{name},{price},{quanity}\n")

        print(self.inventory)
 
  # Add Item in The List

    def add_items_in_list(self):
        self.inventory.clear()

        with open("store.csv" , "r") as file:
            for i in file:
                
                data = i.split(",")
                value = {
                "name" : data[0],
                "price" : data[1],
                "quantity" : data[2]
        }
                self.inventory[data[0]] = value

    # Show Inventory 
    def show_inventory(self):
        
        with open("store.csv" , "r") as file:
            # data = file. readline()
            for i in file:
                data = i.split(",")
                print(f"Name: {data[0]}")
                print(f"Price: {data[1]}")
                print(f"Qty: {data[2]}")
    
    def update_inventory(self,changeBy , what_to_change):
        if len(self.inventory) == 0:
            self.add_items_in_list()
      
        for value in self.inventory:
            
            if changeBy in  value:
                if what_to_change == "price":
                    new_price = input("Enter the new Price: ")
                    self.inventory[change_by]["price"] = new_price
                elif what_to_change == "qty":
                    new_quantity = input("Enter the new Quantity: ")
                    self.inventory[change_by]["quantity"] = new_quantity
                else:
                    print("Invalid choice for what to change (Price/qty).")

        print(self.inventory)
                    
                # user  = input("Enter the New Name : ")
                # self.inventory[]




    


trinity = store()

change_by = input("Enter the Name You Want To Channge: ")
what_to_chanege = input("Enter What to  Change (Price / qty): ")

trinity.update_inventory(change_by , what_to_chanege)
# Out:
# Invalid choice for what to change (Price/qty).
# Invalid choice for what to change (Price/qty).
# Invalid choice for what to change (Price/qty).
# Invalid choice for what to change (Price/qty).
# {'Aman': {'name': 'Aman', 'price': '223', 'quantity': '22\n'}, 'Anurag': {'name': 'Anurag', 'price': '2233', 'quantity': '22\n'}, 'fddd': {'name': 'fddd', 'price': '24423', 'quantity': '22\n'}, 'man': {'name': 'man', 'price': '25523', 'quantity': '22'}}
